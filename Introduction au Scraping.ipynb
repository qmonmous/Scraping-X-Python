# %% [markdown]
# # Introduction au Scraping

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("http://www.echojs.com/")
soup = BeautifulSoup(res.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>
# Echo JS - JavaScript News
# </title>
# <meta content="index" name="robots"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="/css/style.css?v=10" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <script src="/js/jquery.1.6.4.min.js"></script><script src="/js/app.js?v=10"></script>
# </head>
# <body>
# <div class="container">
# <header><h1><a href="/">Echo JS</a> <small>0.11.0</small></h1><nav><a href="/">top</a>
# <a href="/latest/0">latest</a>
# <a href="/random">random</a>
# <a href="/submit">submit</a></nav> <nav id="account"><a href="/login">login / register</a></nav> <a href="#" id="link-menu-mobile">&lt;~&gt;</a></header><div id="content">
# <div id="sitenews">
# Site News : Follow Echo JS on Twitter, our official account is : <a href="https://twitter.com/echojs">@echojs</a>
# </div>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Echo JS - JavaScript News
#   </title>
#   <meta content="index" name="robots"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link href="/css/style.css?v=10" rel="stylesheet" type="text/css"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <script src="/js/jquery.1.6.4.min.js">
#   </script>
#   <script src="/js/app.js?v=10">
#   </script>
#  </head>
#  <body>
#   <div class="container">
#    <header>
#     <h1>
#      <a href="/">
#       Echo JS
#      </a>
#      <small>
#       0.11.0
#      </small>
#     </h1>
#     <nav>
#      <a href="/">
#       top
#      </a>
#      <a href="/latest/0">
#       latest
#      </a>
#      <a href="/random">
#       random
#      </a>
#      <a href="/submit">
#       submit
#      </a>
#     </nav>
#     <nav id="account">
#      <a href="/login">
#       login / register
#      </a>
#     </nav>
# ...

# %%
soup.title
# Out:
# <title>
# Echo JS - JavaScript News
# </title>

# %%
soup.find_all('article')
# Out:
# [<article data-news-id="31713"><a class="uparrow" href="#up">▲</a> <h2><a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a></h2> <address>at wanago.io</address><a class="downarrow" href="#down">▼</a><p><span class="upvotes">1</span> up and <span class="downvotes">0</span> down, posted by <username><a href="/user/mwanago">mwanago</a></username> 7 minutes ago <a href="/news/31713">discuss</a></p></article>,
# ...

# %%
soup.find_all('h2')
# Out:
# [<h2>Top news</h2>,
#  <h2><a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a></h2>,
#  <h2><a href="https://gokoji.com/" rel="nofollow">Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.</a></h2>,
#  <h2><a href="https://bento-starter.netlify.com/" rel="nofollow">Open source full-stack solution for fast PWA development</a></h2>,
#  <h2><a href="https://www.cometchat.com/tutorials/build-a-modern-chat-application-with-react/" rel="nofollow">Build a Modern Chat Application with React</a></h2>,
#  <h2><a href="https://www.cometchat.com/tutorials/build-an-anonymous-group-chat-with-angular-7/" rel="nofollow">Angular JS chat tutorial: Anonymous group chat</a></h2>,
#  <h2><a href="/news/31674" rel="nofollow">EchoJS Vacation Notice</a></h2>,
# ...

# %%
soup.find_all('h2')[2].text
# Out:
# 'Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.'

# %%
soup.select('h2')

# %%
soup.select('h2')[1]
# Out:
# <h2><a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a></h2>

# %%
soup.select('h2 > a')
# Out:
# [<a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a>,
#  <a href="https://gokoji.com/" rel="nofollow">Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.</a>,
#  <a href="https://bento-starter.netlify.com/" rel="nofollow">Open source full-stack solution for fast PWA development</a>,
#  <a href="https://www.cometchat.com/tutorials/build-a-modern-chat-application-with-react/" rel="nofollow">Build a Modern Chat Application with React</a>,
#  <a href="https://www.cometchat.com/tutorials/build-an-anonymous-group-chat-with-angular-7/" rel="nofollow">Angular JS chat tutorial: Anonymous group chat</a>,
#  <a href="/news/31674" rel="nofollow">EchoJS Vacation Notice</a>,
#  <a href="https://mathiasbynens.be/notes/globalthis" rel="nofollow">A horrifying globalThis polyfill in universal JavaScript</a>,
# ...

# %%
soup.select('article > h2')
# Out:
# [<h2><a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a></h2>,
#  <h2><a href="https://gokoji.com/" rel="nofollow">Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.</a></h2>,
#  <h2><a href="https://bento-starter.netlify.com/" rel="nofollow">Open source full-stack solution for fast PWA development</a></h2>,
#  <h2><a href="https://www.cometchat.com/tutorials/build-a-modern-chat-application-with-react/" rel="nofollow">Build a Modern Chat Application with React</a></h2>,
#  <h2><a href="https://www.cometchat.com/tutorials/build-an-anonymous-group-chat-with-angular-7/" rel="nofollow">Angular JS chat tutorial: Anonymous group chat</a></h2>,
#  <h2><a href="/news/31674" rel="nofollow">EchoJS Vacation Notice</a></h2>,
# ...

# %%
soup.select_one('article')
# Out:
# <article data-news-id="31713"><a class="uparrow" href="#up">▲</a> <h2><a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a></h2> <address>at wanago.io</address><a class="downarrow" href="#down">▼</a><p><span class="upvotes">1</span> up and <span class="downvotes">0</span> down, posted by <username><a href="/user/mwanago">mwanago</a></username> 7 minutes ago <a href="/news/31713">discuss</a></p></article>

# %%
soup.select_one('article > h2')
# Out:
# <h2><a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a></h2>

# %%
soup.select_one('article > h2 > a')
# Out:
# <a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a>

# %%
soup.select_one('article > h2 > a').text
# Out:
# 'Node.js TypeScript #12. Introduction to Worker Threads with TypeScript'

# %%
soup.select('article > h2 > a')[0]
# Out:
# <a href="https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/" rel="nofollow">Node.js TypeScript #12. Introduction to Worker Threads with TypeScript</a>

# %%
soup.select('article > h2 > a')[0].get_text()
# Out:
# 'Node.js TypeScript #12. Introduction to Worker Threads with TypeScript'

# %%
len(soup.select('article > h2 > a'))
# Out:
# 30

# %%
for i, val in enumerate(scraped_list):
    print(soup.select('article > h2 > a')[i].get_text())
# Out:
# VS Code Extension: New Remote Development Pack introduced
# Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.
# Licia: Useful Utility Collection with Zero Dependencies:)
# PCI DSS for “Blockchain Based” Crypto Projects
# Node.js TypeScript #12. Introduction to Worker Threads with TypeScript
# Open source full-stack solution for fast PWA development
# Build a Modern Chat Application with React
# Angular JS chat tutorial: Anonymous group chat
# EchoJS Vacation Notice
# 5 things you didn’t know about React DevTools
# A horrifying globalThis polyfill in universal JavaScript
# Getting Started With React Redux Using React
# Npm module that returns user's social network avatar without need of token or API keys
# Introduction to Angular Grid
# Terminal based 404 page with jargon, wikipedia, github and rfc commands
# Image recognition with React & ONNX.js - On Web
# Combination of React and D3
# ...

# %%
soup.select_one('article > h2 > a').get('href')
# Out:
# 'https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/'

# %%
for i, val in enumerate(scraped_list):
    print(soup.select('article > h2 > a')[i].get('href'))
# Out:
# https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/
# https://gokoji.com/
# https://bento-starter.netlify.com/
# https://www.cometchat.com/tutorials/build-a-modern-chat-application-with-react/
# https://www.cometchat.com/tutorials/build-an-anonymous-group-chat-with-angular-7/
# /news/31674
# https://mathiasbynens.be/notes/globalthis
# https://medium.com/@billys.moustakas/vs-code-extension-new-remote-development-pack-introduced-fe3730dde771
# https://blog.logrocket.com/5-things-you-didnt-know-about-react-devtools-2c6e0ef22529
# https://www.js-tutorials.com/react-js/getting-started-with-react-redux-example-using-react/
# https://github.com/eldimious/network-avatar-picker
# https://techshard.com/2019/05/05/introduction-to-angular-grid/
# https://terminal.jcubic.pl/404
# https://heartbeat.fritz.ai/building-an-image-recognition-app-using-onnx-js-c7147f4f291b
# https://medium.com/@icrosil/combination-of-react-and-d3-1fb07b00fb55
# ...

# %%
scraped_list = soup.select('article > h2 > a')

for scraped_item in scraped_list:
    names = scraped_item.get_text()
    links = scraped_item.get('href')
    print('Name: {}\nLink: {}\n'.format(names, links))
# Out:
# Article: VS Code Extension: New Remote Development Pack introduced
# Link: https://medium.com/@billys.moustakas/vs-code-extension-new-remote-development-pack-introduced-fe3730dde771
#
# Article: Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.
# Link: https://gokoji.com/
#
# Article: Licia: Useful Utility Collection with Zero Dependencies:)
# Link: https://licia.liriliri.io/
#
# Article: PCI DSS for “Blockchain Based” Crypto Projects
# Link: https://2muchcoffee.com/blog/pci-dss-for-crypto-projects-blockchain-based/
#
# Article: Node.js TypeScript #12. Introduction to Worker Threads with TypeScript
# Link: https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/
#
# Article: Open source full-stack solution for fast PWA development
# Link: https://bento-starter.netlify.com/
#
# Article: Build a Modern Chat Application with React
# Link: https://www.cometchat.com/tutorials/build-a-modern-chat-application-with-react/
#
# ...

# %%
import csv

#Ouvre un fichier .csv avec 'a' pour 'append'
csvfile = open('scraped.csv', 'w')
#Mode écriture
csvwriter = csv.writer(csvfile)
csvwriter.writerow(['Name', 'Link'])

scraped_list = soup.select('article > h2 > a')

for scraped_item in scraped_list:
    names = scraped_item.get_text()
    links = scraped_item.get('href')
    csvwriter.writerow([names, links])

# %% [markdown]
# ## Bonus

# %%
soup.select_one('article > p > span')
# Out:
# <span class="upvotes">3</span>

# %%
soup.select_one('article > p > span.upvotes').text
# Out:
# '3'

# %%
soup.select_one('article > p > span.downvotes').text
# Out:
# '0'

# %%
import csv

#Ouvre un fichier .csv avec 'a' pour 'append'
csvfile = open('scrapedmore.csv', 'w')
#Mode écriture
csvwriter = csv.writer(csvfile)
csvwriter.writerow(['Name', 'Link', 'Up', 'Down'])

articles = soup.select('article')

for article in articles:
    name = article.select_one('h2 > a').get_text()
    link = article.select_one('h2 > a').get('href')
    up = article.select_one('p > span.upvotes').get_text()
    down = article.select_one('p > span.downvotes').get_text()
    csvwriter.writerow([name, link, up, down])

# %% [markdown]
# ---

# %% [markdown]
# # 1. Import librairies et page web

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("http://www.echojs.com/")
soup = BeautifulSoup(res.text, 'html.parser')
print(soup)

# %% [markdown]
# # 2. Récupération des données

# %%
links = soup.select('article > h2 > a')

data = []

for link in links:
    data.append({
        'title': link.get_text(),
        'url': link.get('href')
    })
    
for post in data:
    print('Name: {}\nLink: {}\n'.format(post['title'], post['url']))
# Out:
# Name: VS Code Extension: New Remote Development Pack introduced
# Link: https://medium.com/@billys.moustakas/vs-code-extension-new-remote-development-pack-introduced-fe3730dde771
#
# Name: Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.
# Link: https://gokoji.com/
#
# Name: Licia: Useful Utility Collection with Zero Dependencies:)
# Link: https://licia.liriliri.io/
#
# Name: PCI DSS for “Blockchain Based” Crypto Projects
# Link: https://2muchcoffee.com/blog/pci-dss-for-crypto-projects-blockchain-based/
#
# Name: Node.js TypeScript #12. Introduction to Worker Threads with TypeScript
# Link: https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/
#
# Name: Open source full-stack solution for fast PWA development
# Link: https://bento-starter.netlify.com/
#
# Name: Build a Modern Chat Application with React
# Link: https://www.cometchat.com/tutorials/build-a-modern-chat-application-with-react/
#
# ...

# %% [markdown]
# # 3. Écriture dans un fichier .csv

# %%
import csv

with open('./echojs.csv', 'w') as f:
    writer = csv.DictWriter(f, fieldnames=['title', 'url'])
    writer.writeheader()
    
    for post in data:
        writer.writerow(post)
