# %% [markdown]
# # Introduction au Scraping

# %% [markdown]
# ## 1. Import librairies et page web

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("http://www.echojs.com/")
soup = BeautifulSoup(res.text, 'html.parser')
print(soup)

# %% [markdown]
# ## 2. Récupération des données

# %%
data = []

links = soup.select('article > h2 > a')

for link in links:
    data.append({
        'title': link.get_text(),
        'url': link.get('href')
    })
    
for post in data:
    print('Name: {}\nLink: {}\n'.format(post['title'], post['url']))
# Out:
# Name: VS Code Extension: New Remote Development Pack introduced
# Link: https://medium.com/@billys.moustakas/vs-code-extension-new-remote-development-pack-introduced-fe3730dde771
#
# Name: Koji is a platform that makes building and deploying full-stack web apps dramatically faster, and easier.
# Link: https://gokoji.com/
#
# Name: Licia: Useful Utility Collection with Zero Dependencies:)
# Link: https://licia.liriliri.io/
#
# Name: PCI DSS for “Blockchain Based” Crypto Projects
# Link: https://2muchcoffee.com/blog/pci-dss-for-crypto-projects-blockchain-based/
#
# Name: Node.js TypeScript #12. Introduction to Worker Threads with TypeScript
# Link: https://wanago.io/2019/05/06/node-js-typescript-12-worker-threads/
#
# Name: Open source full-stack solution for fast PWA development
# Link: https://bento-starter.netlify.com/
#
# Name: Build a Modern Chat Application with React
# Link: https://www.cometchat.com/tutorials/build-a-modern-chat-application-with-react/
#
# Name: Angular JS chat tutorial: Anonymous group chat
# Link: https://www.cometchat.com/tutorials/build-an-anonymous-group-chat-with-angular-7/
#
# Name: EchoJS Vacation Notice
# Link: /news/31674
#
# Name: 5 things you didn’t know about React DevTools
# Link: https://blog.logrocket.com/5-things-you-didnt-know-about-react-devtools-2c6e0ef22529
#
# Name: A horrifying globalThis polyfill in universal JavaScript
# Link: https://mathiasbynens.be/notes/globalthis
#
# Name: Getting Started With React Redux Using React
# Link: https://www.js-tutorials.com/react-js/getting-started-with-react-redux-example-using-react/
#
# Name: Npm module that returns user's social network avatar without need of token or API keys
# Link: https://github.com/eldimious/network-avatar-picker
#
# Name: Introduction to Angular Grid
# Link: https://techshard.com/2019/05/05/introduction-to-angular-grid/
#
# Name: Terminal based 404 page with jargon, wikipedia, github and rfc commands
# Link: https://terminal.jcubic.pl/404
#
# Name: Image recognition with React & ONNX.js - On Web
# Link: https://heartbeat.fritz.ai/building-an-image-recognition-app-using-onnx-js-c7147f4f291b
#
# Name: Combination of React and D3
# Link: https://medium.com/@icrosil/combination-of-react-and-d3-1fb07b00fb55
#
# Name: React Hooks/Suspense and a Functional Programming: Hooks/Suspense as Applicative/Monadic syntax
# Link: https://medium.freecodecamp.org/when-to-use-react-suspense-vs-react-hooks-f66ef94cb54f
#
# Name: A Starter Project for Building Distributed, Message Based Node Apps
# Link: https://github.com/node-ts/bus-starter
#
# Name: React Navigation vs. React Native Navigation: Which is right for you?
# Link: https://blog.logrocket.com/react-navigation-vs-react-native-navigation-which-is-right-for-you-3d47c1cd1d63
#
# Name: Node Express Analytics Dashboard with Cube.js
# Link: https://cube.dev/blog/node-express-analytics-dashboard-with-cubejs/
#
# Name: 10 JavaScript Charting Libraries for Every Data Visualization Need
# Link: https://hackernoon.com/10-javascript-charting-libraries-data-visualization-b77523d23372
#
# Name: Facebook makes its first browser API contribution
# Link: https://techcrunch.com/2019/04/22/facebook-makes-its-first-browser-api-contribution/
#
# Name: Introduction to Vue Render Functions (w/ examples)
# Link: https://snipcart.com/blog/vue-render-functions
#
# Name: React: JSX & Rendering
# Link: https://itnext.io/react-jsx-rendering-4405d3a3d6c3
#
# Name: How to Write Node.Js Applications in Typescript
# Link: https://medium.com/@freek_mencke/how-to-write-node-js-applications-in-typescript-a54af696f66?source=friends_link&amp;sk=2576a44b4fed8e1a49c2513fc2ac0fd3
#
# Name: Redux Agent · Reducer-driven effects for React/Redux apps
# Link: https://redux-agent.org
#
# Name: LIPS Is Pretty Simple - lisp in JavaScript with full macro support
# Link: https://jcubic.github.io/lips/
#
# Name: Using Boxing to prevent distribution of conditional types in typescript
# Link: https://lorefnon.tech/2019/05/02/using-boxing-to-prevent-distribution-of-conditional-types/
#
# Name: A better strategy for long term caching
# Link: https://medium.com/@sujankanwar/a-better-strategy-for-long-term-caching-d41f3c63cb74?source=friends_link&sk=e714b2838a48b83a7fa90377faed8e54

# %% [markdown]
# ## 3. Écriture dans un fichier .csv

# %%
import csv

with open('./echojs.csv', 'w') as f:
    writer = csv.DictWriter(f, fieldnames=['title', 'url'])
    writer.writeheader()
    
    for post in data:
        writer.writerow(post)

# %% [markdown]
# ---

# %% [markdown]
# # Reformater pour du stockage en JSON

# %% [markdown]
# Essayons de récupérer les informations suivantes pour chaque article du site [HackerNews](https://news.ycombinator.com) :
# - id
# - url
# - title
# - points
# - author
# - comments
#
# Nous les stockerons ensuite au format JSON.

# %% [markdown]
# ## 1. Import librairies et page web

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://news.ycombinator.com")
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.prettify())
# Out:
# <html op="news">
#  <head>
#   <meta content="origin" name="referrer"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="news.css?0cBqUHCbnKTxrOsi1kz1" rel="stylesheet" type="text/css"/>
#   <link href="favicon.ico" rel="shortcut icon"/>
#   <link href="rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <title>
#    Hacker News
#   </title>
#  </head>
#  <body>
#   <center>
#    <table bgcolor="#f6f6ef" border="0" cellpadding="0" cellspacing="0" id="hnmain" width="85%">
#     <tr>
#      <td bgcolor="#ff6600">
#       <table border="0" cellpadding="0" cellspacing="0" style="padding:2px" width="100%">
#        <tr>
#         <td style="width:18px;padding-right:4px">
#          <a href="https://news.ycombinator.com">
#           <img height="18" src="y18.gif" style="border:1px white solid;" width="18"/>
#          </a>
#         </td>
#         <td style="line-height:12pt; height:10px;">
#          <span class="pagetop">
#           <b class="hnname">
#            <a href="news">
#             Hacker News
#            </a>
#           </b>
#           <a href="newest">
#            new
#           </a>
#           |
#           <a href="front">
#            past
#           </a>
#           |
#           <a href="newcomments">
#            comments
#           </a>
#           |
#           <a href="ask">
#            ask
#           </a>
#           |
#           <a href="show">
#            show
#           </a>
#           |
#           <a href="jobs">
#            jobs
#           </a>
#           |
#           <a href="submit">
#            submit
#           </a>
#          </span>
#         </td>
#         <td style="text-align:right;padding-right:4px;">
#          <span class="pagetop">
#           <a href="login?goto=news">
#            login
#           </a>
#          </span>
#         </td>
#        </tr>
#       </table>
#      </td>
#     </tr>
#     <tr id="pagespace" style="height:10px" title="">
#     </tr>
#     <tr>
#      <td>
#       <table border="0" cellpadding="0" cellspacing="0" class="itemlist">
#        <tr class="athing" id="19837981">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           1.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19837981&amp;how=up&amp;goto=news" id="up_19837981">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://dave.cheney.net/paste/clear-is-better-than-clever.pdf">
#           Clear is better than clever [pdf]
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=cheney.net">
#            <span class="sitestr">
#             cheney.net
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19837981">
#           100 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=ngaut">
#           ngaut
#          </a>
#          <span class="age">
#           <a href="item?id=19837981">
#            2 hours ago
#           </a>
#          </span>
#          <span id="unv_19837981">
#          </span>
#          |
#          <a href="hide?id=19837981&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19837981">
#           30 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19838123">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           2.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19838123&amp;how=up&amp;goto=news" id="up_19838123">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://arxiv.org/abs/1905.01051">
#           Browser Fingerprinting: A Survey
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=arxiv.org">
#            <span class="sitestr">
#             arxiv.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19838123">
#           35 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=Anon84">
#           Anon84
#          </a>
#          <span class="age">
#           <a href="item?id=19838123">
#            1 hour ago
#           </a>
#          </span>
#          <span id="unv_19838123">
#          </span>
#          |
#          <a href="hide?id=19838123&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19838123">
#           13 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19838355">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           3.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19838355&amp;how=up&amp;goto=news" id="up_19838355">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.bbc.co.uk/news/world-us-canada-48138441">
#           Why rich convicts hire prison consultants
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=bbc.co.uk">
#            <span class="sitestr">
#             bbc.co.uk
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19838355">
#           13 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=iamben">
#           iamben
#          </a>
#          <span class="age">
#           <a href="item?id=19838355">
#            51 minutes ago
#           </a>
#          </span>
#          <span id="unv_19838355">
#          </span>
#          |
#          <a href="hide?id=19838355&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19838355">
#           1 comment
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19836922">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           4.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19836922&amp;how=up&amp;goto=news" id="up_19836922">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://raulgrell.github.io/tetris/">
#           Tetris clone written in Zig running on WebGL and WebAssembly
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=raulgrell.github.io">
#            <span class="sitestr">
#             raulgrell.github.io
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19836922">
#           130 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=Hoppetosse">
#           Hoppetosse
#          </a>
#          <span class="age">
#           <a href="item?id=19836922">
#            7 hours ago
#           </a>
#          </span>
#          <span id="unv_19836922">
#          </span>
#          |
#          <a href="hide?id=19836922&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19836922">
#           33 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19835608">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           5.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19835608&amp;how=up&amp;goto=news" id="up_19835608">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.nytimes.com/2019/05/05/business/boeing-737-max-warning-light.html">
#           Boeing Believed a 737 Max Warning Light Was Standard
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=nytimes.com">
#            <span class="sitestr">
#             nytimes.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19835608">
#           384 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=aaronbrethorst">
#           aaronbrethorst
#          </a>
#          <span class="age">
#           <a href="item?id=19835608">
#            13 hours ago
#           </a>
#          </span>
#          <span id="unv_19835608">
#          </span>
#          |
#          <a href="hide?id=19835608&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19835608">
#           247 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19837968">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           6.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19837968&amp;how=up&amp;goto=news" id="up_19837968">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="http://www.cabinetmagazine.org/issues/64/mikanowski.php?">
#           Language at the End of the World (2017)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=cabinetmagazine.org">
#            <span class="sitestr">
#             cabinetmagazine.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19837968">
#           14 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=aaronharnly">
#           aaronharnly
#          </a>
#          <span class="age">
#           <a href="item?id=19837968">
#            2 hours ago
#           </a>
#          </span>
#          <span id="unv_19837968">
#          </span>
#          |
#          <a href="hide?id=19837968&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19837968">
#           discuss
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19838229">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           7.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19838229&amp;how=up&amp;goto=news" id="up_19838229">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.washingtonpost.com/climate-environment/2019/05/06/one-million-species-face-extinction-un-panel-says-humans-will-suffer-result/">
#           One million species face extinction, U.N. panel says
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=washingtonpost.com">
#            <span class="sitestr">
#             washingtonpost.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19838229">
#           57 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=uptown">
#           uptown
#          </a>
#          <span class="age">
#           <a href="item?id=19838229">
#            1 hour ago
#           </a>
#          </span>
#          <span id="unv_19838229">
#          </span>
#          |
#          <a href="hide?id=19838229&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19838229">
#           11 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19812705">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           8.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19812705&amp;how=up&amp;goto=news" id="up_19812705">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://lteo.net/blog/2019/04/27/carolinacon-15-writing-exploit-resistant-code-with-openbsd/">
#           Writing Exploit-Resistant Code with OpenBSD
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=lteo.net">
#            <span class="sitestr">
#             lteo.net
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19812705">
#           117 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=lelf">
#           lelf
#          </a>
#          <span class="age">
#           <a href="item?id=19812705">
#            9 hours ago
#           </a>
#          </span>
#          <span id="unv_19812705">
#          </span>
#          |
#          <a href="hide?id=19812705&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19812705">
#           16 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19835615">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           9.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19835615&amp;how=up&amp;goto=news" id="up_19835615">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="http://www-users.mat.umk.pl/~adwid/materialy/doc/church.pdf">
#           The Impact of the Lambda Calculus (1997) [pdf]
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=mat.umk.pl">
#            <span class="sitestr">
#             mat.umk.pl
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19835615">
#           56 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=espeed">
#           espeed
#          </a>
#          <span class="age">
#           <a href="item?id=19835615">
#            6 hours ago
#           </a>
#          </span>
#          <span id="unv_19835615">
#          </span>
#          |
#          <a href="hide?id=19835615&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19835615">
#           2 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19836148">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           10.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19836148&amp;how=up&amp;goto=news" id="up_19836148">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.fcc.gov/consumers/guides/one-ring-phone-scam">
#           'One Ring' Phone Scam
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=fcc.gov">
#            <span class="sitestr">
#             fcc.gov
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19836148">
#           138 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=daegloe">
#           daegloe
#          </a>
#          <span class="age">
#           <a href="item?id=19836148">
#            10 hours ago
#           </a>
#          </span>
#          <span id="unv_19836148">
#          </span>
#          |
#          <a href="hide?id=19836148&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19836148">
#           177 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19818466">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           11.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19818466&amp;how=up&amp;goto=news" id="up_19818466">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="http://www.docbastard.net/2019/05/true-surprise.html">
#           True Surprise
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=docbastard.net">
#            <span class="sitestr">
#             docbastard.net
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19818466">
#           150 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=dmit">
#           dmit
#          </a>
#          <span class="age">
#           <a href="item?id=19818466">
#            13 hours ago
#           </a>
#          </span>
#          <span id="unv_19818466">
#          </span>
#          |
#          <a href="hide?id=19818466&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19818466">
#           16 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19835962">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           12.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19835962&amp;how=up&amp;goto=news" id="up_19835962">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://projecteuclid.org/download/pdf_1/euclid.ss/1009213726">
#           Statistical Modeling: The Two Cultures (2001) [pdf]
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=projecteuclid.org">
#            <span class="sitestr">
#             projecteuclid.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19835962">
#           147 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=michael_fine">
#           michael_fine
#          </a>
#          <span class="age">
#           <a href="item?id=19835962">
#            11 hours ago
#           </a>
#          </span>
#          <span id="unv_19835962">
#          </span>
#          |
#          <a href="hide?id=19835962&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19835962">
#           20 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19836028">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           13.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19836028&amp;how=up&amp;goto=news" id="up_19836028">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.japantimes.co.jp/news/2019/05/04/business/tech/momo-3-becomes-first-privately-developed-japanese-rocket-reach-outer-space/#.XM-C3BYpDYU">
#           Momo-3 is Japan's first private rocket to reach space
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=japantimes.co.jp">
#            <span class="sitestr">
#             japantimes.co.jp
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19836028">
#           105 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=aerophilic">
#           aerophilic
#          </a>
#          <span class="age">
#           <a href="item?id=19836028">
#            11 hours ago
#           </a>
#          </span>
#          <span id="unv_19836028">
#          </span>
#          |
#          <a href="hide?id=19836028&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19836028">
#           19 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19827993">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           14.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19827993&amp;how=up&amp;goto=news" id="up_19827993">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="http://pages.tacc.utexas.edu/~eijkhout/istc/html/index.html">
#           Introduction to High-Performance Scientific Computing (2014)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=utexas.edu">
#            <span class="sitestr">
#             utexas.edu
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19827993">
#           139 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=ingve">
#           ingve
#          </a>
#          <span class="age">
#           <a href="item?id=19827993">
#            15 hours ago
#           </a>
#          </span>
#          <span id="unv_19827993">
#          </span>
#          |
#          <a href="hide?id=19827993&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19827993">
#           1 comment
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19817488">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           15.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19817488&amp;how=up&amp;goto=news" id="up_19817488">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://utteranc.es/">
#           Utterances: Lightweight comments widget built on GitHub issues
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=utteranc.es">
#            <span class="sitestr">
#             utteranc.es
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19817488">
#           34 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=lelf">
#           lelf
#          </a>
#          <span class="age">
#           <a href="item?id=19817488">
#            6 hours ago
#           </a>
#          </span>
#          <span id="unv_19817488">
#          </span>
#          |
#          <a href="hide?id=19817488&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19817488">
#           15 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19837230">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           16.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19837230&amp;how=up&amp;goto=news" id="up_19837230">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.wired.com/story/future-book-is-here-but-not-what-we-expected/">
#           The 'Future Book' Is Here, but It's Not What We Expected (2018)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=wired.com">
#            <span class="sitestr">
#             wired.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19837230">
#           26 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=cmod">
#           cmod
#          </a>
#          <span class="age">
#           <a href="item?id=19837230">
#            5 hours ago
#           </a>
#          </span>
#          <span id="unv_19837230">
#          </span>
#          |
#          <a href="hide?id=19837230&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19837230">
#           13 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19838433">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           17.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19838433&amp;how=up&amp;goto=news" id="up_19838433">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://medium.com/personal-growth/what-if-controlling-unhappiness-contains-the-secret-to-happiness-acd96242970c">
#           What If Unhappiness Contains the Secret to Happiness?
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=medium.com">
#            <span class="sitestr">
#             medium.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19838433">
#           7 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=kelvinp">
#           kelvinp
#          </a>
#          <span class="age">
#           <a href="item?id=19838433">
#            35 minutes ago
#           </a>
#          </span>
#          <span id="unv_19838433">
#          </span>
#          |
#          <a href="hide?id=19838433&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19838433">
#           discuss
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19831087">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           18.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19831087&amp;how=up&amp;goto=news" id="up_19831087">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://grist.org/living/mushroom-burial-suit-turns-dead-bodies-into-clean-compost/">
#           Mushroom burial suit turns dead bodies into clean compost (2016)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=grist.org">
#            <span class="sitestr">
#             grist.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19831087">
#           44 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=gscott">
#           gscott
#          </a>
#          <span class="age">
#           <a href="item?id=19831087">
#            9 hours ago
#           </a>
#          </span>
#          <span id="unv_19831087">
#          </span>
#          |
#          <a href="hide?id=19831087&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19831087">
#           24 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19833944">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           19.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19833944&amp;how=up&amp;goto=news" id="up_19833944">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.nytimes.com/2019/04/29/fashion/smith-college-clothing-collection.html" rel="nofollow">
#           The Smith College Historic Clothing Collection
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=nytimes.com">
#            <span class="sitestr">
#             nytimes.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19833944">
#           7 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=ascertain">
#           ascertain
#          </a>
#          <span class="age">
#           <a href="item?id=19833944">
#            2 hours ago
#           </a>
#          </span>
#          <span id="unv_19833944">
#          </span>
#          |
#          <a href="hide?id=19833944&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19833944">
#           discuss
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19828113">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           20.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19828113&amp;how=up&amp;goto=news" id="up_19828113">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.thenewatlantis.com/publications/do-elephants-have-souls">
#           Do Elephants Have Souls? (2013)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=thenewatlantis.com">
#            <span class="sitestr">
#             thenewatlantis.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19828113">
#           124 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=seinundzeit">
#           seinundzeit
#          </a>
#          <span class="age">
#           <a href="item?id=19828113">
#            14 hours ago
#           </a>
#          </span>
#          <span id="unv_19828113">
#          </span>
#          |
#          <a href="hide?id=19828113&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19828113">
#           73 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19830860">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           21.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19830860&amp;how=up&amp;goto=news" id="up_19830860">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://bitbucket.org/duangle/scopes/wiki/Home">
#           Scopes – Retargetable programming language and infrastructure
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=bitbucket.org">
#            <span class="sitestr">
#             bitbucket.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19830860">
#           93 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=homarp">
#           homarp
#          </a>
#          <span class="age">
#           <a href="item?id=19830860">
#            12 hours ago
#           </a>
#          </span>
#          <span id="unv_19830860">
#          </span>
#          |
#          <a href="hide?id=19830860&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19830860">
#           28 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19836430">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           22.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19836430&amp;how=up&amp;goto=news" id="up_19836430">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://create.arduino.cc/projecthub/codedigs/build-a-battlebot-controlled-with-a-ps2-controller-fbc033">
#           Show HN: BattleBots Made by 5th to 8th Graders in Robotics Club
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=arduino.cc">
#            <span class="sitestr">
#             arduino.cc
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19836430">
#           34 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=20years">
#           20years
#          </a>
#          <span class="age">
#           <a href="item?id=19836430">
#            9 hours ago
#           </a>
#          </span>
#          <span id="unv_19836430">
#          </span>
#          |
#          <a href="hide?id=19836430&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19836430">
#           2 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19832348">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           23.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19832348&amp;how=up&amp;goto=news" id="up_19832348">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.phdcc.com/javaart2.html">
#           Netscape's Internet Foundation Classes (1996)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=phdcc.com">
#            <span class="sitestr">
#             phdcc.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19832348">
#           29 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=ptx">
#           ptx
#          </a>
#          <span class="age">
#           <a href="item?id=19832348">
#            8 hours ago
#           </a>
#          </span>
#          <span id="unv_19832348">
#          </span>
#          |
#          <a href="hide?id=19832348&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19832348">
#           7 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19817584">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           24.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19817584&amp;how=up&amp;goto=news" id="up_19817584">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://economics.harvard.edu/files/economics/files/ms28533.pdf">
#           The Rate of Return on Everything, 1870–2015 [pdf]
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=economics.harvard.edu">
#            <span class="sitestr">
#             economics.harvard.edu
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19817584">
#           372 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=dredmorbius">
#           dredmorbius
#          </a>
#          <span class="age">
#           <a href="item?id=19817584">
#            18 hours ago
#           </a>
#          </span>
#          <span id="unv_19817584">
#          </span>
#          |
#          <a href="hide?id=19817584&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19817584">
#           178 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19837510">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           25.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19837510&amp;how=up&amp;goto=news" id="up_19837510">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://linuxhint.com/zfs_vs_xfs/">
#           File Systems – ZFS vs. XFS
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=linuxhint.com">
#            <span class="sitestr">
#             linuxhint.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19837510">
#           29 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=truth_seeker">
#           truth_seeker
#          </a>
#          <span class="age">
#           <a href="item?id=19837510">
#            4 hours ago
#           </a>
#          </span>
#          <span id="unv_19837510">
#          </span>
#          |
#          <a href="hide?id=19837510&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19837510">
#           20 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19832109">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           26.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19832109&amp;how=up&amp;goto=news" id="up_19832109">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://openreview.net/pdf?id=BJl6AjC5F7">
#           Learning to Represent Edits
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=openreview.net">
#            <span class="sitestr">
#             openreview.net
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19832109">
#           25 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=godelmachine">
#           godelmachine
#          </a>
#          <span class="age">
#           <a href="item?id=19832109">
#            10 hours ago
#           </a>
#          </span>
#          <span id="unv_19832109">
#          </span>
#          |
#          <a href="hide?id=19832109&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19832109">
#           2 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19837447">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           27.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19837447&amp;how=up&amp;goto=news" id="up_19837447">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://newatlas.com/arsenic-breathing-microbes-ocean/59549/">
#           Organisms that breathe arsenic discovered in the Pacific Ocean
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=newatlas.com">
#            <span class="sitestr">
#             newatlas.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19837447">
#           26 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=sahin-boydas">
#           sahin-boydas
#          </a>
#          <span class="age">
#           <a href="item?id=19837447">
#            4 hours ago
#           </a>
#          </span>
#          <span id="unv_19837447">
#          </span>
#          |
#          <a href="hide?id=19837447&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19837447">
#           5 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19838121">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           28.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19838121&amp;how=up&amp;goto=news" id="up_19838121">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="item?id=19838121">
#           Tell HN: My usability pet peeve – am/pm times with a leading zero
#          </a>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19838121">
#           14 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=FearNotDaniel">
#           FearNotDaniel
#          </a>
#          <span class="age">
#           <a href="item?id=19838121">
#            1 hour ago
#           </a>
#          </span>
#          <span id="unv_19838121">
#          </span>
#          |
#          <a href="hide?id=19838121&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19838121">
#           13 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19833746">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           29.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19833746&amp;how=up&amp;goto=news" id="up_19833746">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.cbc.ca/news/business/cbsa-boarder-security-search-phone-travellers-openmedia-1.5119017">
#           Canada Border Services seizes lawyer's phone, laptop for not sharing passwords
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=cbc.ca">
#            <span class="sitestr">
#             cbc.ca
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19833746">
#           862 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=cpncrunch">
#           cpncrunch
#          </a>
#          <span class="age">
#           <a href="item?id=19833746">
#            19 hours ago
#           </a>
#          </span>
#          <span id="unv_19833746">
#          </span>
#          |
#          <a href="hide?id=19833746&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19833746">
#           410 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="19834432">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           30.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=19834432&amp;how=up&amp;goto=news" id="up_19834432">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://ftp.mozilla.org/pub/firefox/releases/66.0.4/">
#           Firefox 66.0.4 is out, fixes disabled add-ons
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=ftp.mozilla.org">
#            <span class="sitestr">
#             ftp.mozilla.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_19834432">
#           452 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=akyuu">
#           akyuu
#          </a>
#          <span class="age">
#           <a href="item?id=19834432">
#            16 hours ago
#           </a>
#          </span>
#          <span id="unv_19834432">
#          </span>
#          |
#          <a href="hide?id=19834432&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=19834432">
#           323 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="morespace" style="height:10px">
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="title">
#          <a class="morelink" href="news?p=2" rel="next">
#           More
#          </a>
#         </td>
#        </tr>
#       </table>
#      </td>
#     </tr>
#     <tr>
#      <td>
#       <img height="10" src="s.gif" width="0"/>
#       <table cellpadding="1" cellspacing="0" width="100%">
#        <tr>
#         <td bgcolor="#ff6600">
#         </td>
#        </tr>
#       </table>
#       <br/>
#       <center>
#        <span class="yclinks">
#         <a href="newsguidelines.html">
#          Guidelines
#         </a>
#         |
#         <a href="newsfaq.html">
#          FAQ
#         </a>
#         |
#         <a href="mailto:hn@ycombinator.com">
#          Support
#         </a>
#         |
#         <a href="https://github.com/HackerNews/API">
#          API
#         </a>
#         |
#         <a href="security.html">
#          Security
#         </a>
#         |
#         <a href="lists">
#          Lists
#         </a>
#         |
#         <a href="bookmarklet.html" rel="nofollow">
#          Bookmarklet
#         </a>
#         |
#         <a href="http://www.ycombinator.com/legal/">
#          Legal
#         </a>
#         |
#         <a href="http://www.ycombinator.com/apply/">
#          Apply to YC
#         </a>
#         |
#         <a href="mailto:hn@ycombinator.com">
#          Contact
#         </a>
#        </span>
#        <br/>
#        <br/>
#        <form action="//hn.algolia.com/" method="get">
#         Search:
#         <input autocapitalize="off" autocomplete="false" autocorrect="off" name="q" size="17" spellcheck="false" type="text" value=""/>
#        </form>
#       </center>
#      </td>
#     </tr>
#    </table>
#   </center>
#  </body>
#  <script src="hn.js?0cBqUHCbnKTxrOsi1kz1" type="text/javascript">
#  </script>
# </html>

# %% [markdown]
# ## 2. Récupération et préparation des données

# %%
data = []

for tr in soup.select("tr.athing"):
    sibling = tr.find_next_sibling()
    link = tr.select_one('a.storylink')
    
def get_comments(elem):
    #Retrieving number of comments from target sibling element.
    text = elem.get_text().strip()
    
    if text == 'discuss':
        return 0
    
    return int(text.split('comment')[0].strip())

def get_user(elem):
    #Retrieving user id from target sibling element.
    if elem is None:
        return ''
    return elem.get_text().strip()

for tr in soup.select('tr.athing'):
    sibling = tr.find_next_sibling()
    link = tr.select_one('a.storylink')
    
    post = {
        'id': tr.get('id'),
        'url': link.get('href'),
        'title': link.get_text(),
        'points': int(sibling
                      .select_one('.score')
                      .get_text().split(' points')[0]
                      .strip()),
        'comments': get_comments(sibling.select('a')[-1]),
        'author': get_user(sibling.select_one('a[href^="user?"]'))
    }

# %% [markdown]
# ## 3. Écriture dans un fichier .json

# %%
import json

with open('./hackernews.json', 'w') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ---

# %% [markdown]
# # Scraper le web moderne (PWA)
#
# Dans le web moderne, l'expansion des PWA (Progressive Web App) met des bâtons dans les roues du scraping classique. En effet, le HTML ne s'affiche plus car il est contenu directement dans le JavaScript.
# Pour lire ce HTML, on peut décider d'éxecuter le JavaScript dans un navigateur émulé grâce à [Selenium](https://selenium-python.readthedocs.io/) par exemple.

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://angular2-hn.firebaseapp.com/news/1")
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Angular 2 HN
#   </title>
#   <base href="/"/>
#   <meta content="A Hacker News client built with Angular CLI, RxJS and Webpack" name="description">
#    <meta content="summary" name="twitter:card"/>
#    <meta content="@hdjirdeh" name="twitter:site"/>
#    <meta content="Angular 2 HN" name="twitter:title"/>
#    <meta content="A Hacker News client built with Angular CLI, RxJS and Webpack" name="twitter:description"/>
#    <meta content="@hdjirdeh" name="twitter:creator"/>
#    <meta content="assets/images/logo-loading.png" name="twitter:image"/>
#    <meta content="Angular 2 HN" property="og:title">
#     <meta content="website" property="og:type">
#      <meta content="https://angular2-hn.firebaseapp.com/" property="og:url">
#       <meta content="assets/images/logo-loading.png" property="og:image">
#        <meta content="A Hacker News client built with Angular CLI, RxJS and Webpack" property="og:description">
#         <meta content="Angular 2 HN" property="og:site_name">
#          <meta content="10202985971279760" property="fb:admins"/>
#          <meta content="width=device-width, initial-scale=1" name="viewport"/>
#          <meta content="#b92b27" name="theme-color"/>
#          <meta content="#b92b27" name="msapplication-TileColor"/>
#          <meta content="assets/icons/mstile-150x150.png" name="msapplication-TileImage"/>
#          <meta content="assets/icons/browserconfig.xml" name="msapplication-config"/>
#          <meta content="yes" name="apple-mobile-web-app-capable"/>
#          <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#          <link href="/manifest.json" rel="manifest"/>
#          <link color="#b92b27" href="assets/icons/safari-pinned-tab.svg" rel="mask-icon"/>
#          <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#          <link href="assets/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#          <link href="assets/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#          <link href="assets/icons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#          <link href="assets/icons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#          <link href="assets/icons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#          <link href="assets/icons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#          <style>
#           #skip a {  position:absolute;  left:-10000px;  top:auto;  width:1px;  height:1px;  overflow:hidden;  }
#     #skip a:focus {  position:static;  width:auto;  height:auto;  }
#          </style>
#          <link as="script" href="main.5fa6447fa2195a4ac7dd.bundle.js" rel="preload"/>
#          <style>
#           .default .body-cover{background:#fff}@media only screen and (max-width:768px){.default .body-cover{background:#fff}}.default .wrapper{background:#f5f5f5;color:#000}@media only screen and (max-width:768px){.default .wrapper{background:#fff}}.default .wrapper a{color:#000}.default .wrapper a:visited{color:#696969}.default .wrapper #header{background:#b92b27;border-bottom:2px solid #b92b27}.default .wrapper .logo-inner{background:#fff}.default .wrapper .nav a{color:#b92b27}@media only screen and (max-width:768px){.default .wrapper .nav a{color:#b92b27}}.default .wrapper #footer{border-top:2px solid #b92b27}.default .wrapper #footer a{color:#b92b27}.default .wrapper .deleted-meta,.default .wrapper .domain,.default .wrapper .meta,.default .wrapper .subtext,.default .wrapper .subtext-laptop,.default .wrapper .subtext-palm{color:#696969}.default .wrapper .deleted-meta a,.default .wrapper .domain a,.default .wrapper .meta a,.default .wrapper .subtext-laptop a,.default .wrapper .subtext-palm a,.default .wrapper .subtext a{color:#b92b27}.default .wrapper .popup{background:#b92b27}.default .wrapper .item-header{border-bottom:2px solid #b92b27}@media only screen and (max-width:768px){.default .wrapper .item-header{background:#fff}}.default .wrapper .pollContent .pollBar{background:#b92b27}.default .wrapper .loader{color:#b92b27;background:#b92b27}.default .wrapper .loader:after,.default .wrapper .loader:before{background:#b92b27}@media only screen and (max-width:768px){.default .wrapper .job-header{border-bottom:2px solid #b92b27}}@media only screen and (max-width:768px){.default .wrapper .back-button{border-top:.3rem solid #b92b27;border-right:.3rem solid #b92b27}}.default .wrapper .error-section .skull .head{background-color:#b92b27}.default .wrapper .error-section .skull .head:after,.default .wrapper .error-section .skull .head:before{background-color:#f5f5f5}@media only screen and (max-width:768px){.default .wrapper .error-section .skull .head:after,.default .wrapper .error-section .skull .head:before{background-color:#fff}}.default .wrapper .error-section .skull .head .crack{background-color:#f5f5f5}@media only screen and (max-width:768px){.default .wrapper .error-section .skull .head .crack{background-color:#fff}}.default .wrapper .error-section .skull .head .crack:before{border-top:25px solid #f5f5f5}@media only screen and (max-width:768px){.default .wrapper .error-section .skull .head .crack:before{border-top:25px solid #fff}}.default .wrapper .error-section .skull .mouth{background-color:#b92b27}.default .wrapper .error-section .skull .mouth:before{background-color:#f5f5f5}@media only screen and (max-width:768px){.default .wrapper .error-section .skull .mouth:before{background-color:#fff}}.default .wrapper .error-section .skull .teeth{background-color:#f5f5f5}@media only screen and (max-width:768px){.default .wrapper .error-section .skull .teeth{background-color:#fff}}.default .wrapper .error-section .skull .teeth:after,.default .wrapper .error-section .skull .teeth:before{background-color:#f5f5f5}@media only screen and (max-width:768px){.default .wrapper .error-section .skull .teeth:after,.default .wrapper .error-section .skull .teeth:before{background-color:#fff}}.default .wrapper .main-details .name,.default .wrapper .main-details .right{color:#b92b27}.night .body-cover{background:#37474f}@media only screen and (max-width:768px){.night .body-cover{background:#263238}}.night .wrapper{background:#263238;color:hsla(0,0%,100%,.7)}@media only screen and (max-width:768px){.night .wrapper{background:#263238}}.night .wrapper a{color:hsla(0,0%,100%,.7)}.night .wrapper a:visited{color:#999}.night .wrapper #header{background:#263238;border-bottom:2px solid #00c0ff}.night .wrapper .logo-inner{background:#263238}.night .wrapper .nav a{color:#00c0ff}@media only screen and (max-width:768px){.night .wrapper .nav a{color:#00c0ff}}.night .wrapper #footer{border-top:2px solid #00c0ff}.night .wrapper #footer a{color:#00c0ff}.night .wrap ...
#          </style>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="skip">
#    <a href="#content">
#     skip to navigation
#    </a>
#   </div>
#   <app-root>
#   </app-root>
#   <div class="app-loader" id="content">
#    <img alt="Logo" class="logo" src="assets/images/logo.svg"/>
#    <noscript>
#     <h4 style="font-family: 'HelveticaNeue-Light', 'Helvetica Neue Light', 'Helvetica Neue', Helvetica;">
#      Sorry, JavaScript needs to be enabled in order to run this application.
#     </h4>
#    </noscript>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-66348622-3', 'auto');
#   </script>
#   <script async="" type="text/javascript">
#    !function(e){function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}var r=window.webpackJsonp;window.webpackJsonp=function(t,c,a){for(var u,i,f,l=0,s=[];l<t.length;l++)i=t[l],o[i]&&s.push(o[i][0]),o[i]=0;for(u in c)Object.prototype.hasOwnProperty.call(c,u)&&(e[u]=c[u]);for(r&&r(t,c,a);s.length;)s.shift()();if(a)for(l=0;l<a.length;l++)f=n(n.s=a[l]);return f};var t={},o={4:0};n.e=function(e){function r(){u.onerror=u.onload=null,clearTimeout(i);var n=o[e];0!==n&&(n&&n[1](new Error("Loading chunk "+e+" failed.")),o[e]=void 0)}var t=o[e];if(0===t)return new Promise(function(e){e()});if(t)return t[2];var c=new Promise(function(n,r){t=o[e]=[n,r]});t[2]=c;var a=document.getElementsByTagName("head")[0],u=document.createElement("script");u.type="text/javascript",u.charset="utf-8",u.async=!0,u.timeout=12e4,n.nc&&u.setAttribute("nonce",n.nc),u.src=n.p+""+e+"."+{0:"bcacfaf04e69b27b4c55",1:"b8a77c7554750c9c759b",2:"5fa6447fa2195a4ac7dd",3:"e47380b70646ff320442"}[e]+".chunk.js";var i=setTimeout(r,12e4);return u.onerror=u.onload=r,a.appendChild(u),c},n.m=e,n.c=t,n.d=function(e,r,t){n.o(e,r)||Object.defineProperty(e,r,{configurable:!1,enumerable:!0,get:t})},n.n=function(e){var r=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(r,"a",r),r},n.o=function(e,n){return Object.prototype.hasOwnProperty.call(e,n)},n.p="",n.oe=function(e){throw console.error(e),e}}([]);
#   </script>
#   <script async="" src="main.5fa6447fa2195a4ac7dd.bundle.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# > En faisant une requête à une PWA, on remarque en effet qu'on ne récupère pas le contenu de la page.

# %%
soup.select('li')
# Out:
# []
